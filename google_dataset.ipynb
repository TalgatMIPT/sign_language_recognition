# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from keras.datasets import mnist
# %matplotlib inline

# %%
# Загружаем картинки
from os import listdir, walk
from os.path import isfile, join
def take_all_pictures_names(path):
    paths = []
    targets = []
    for x in walk(path):
        for y in x[2]:
            paths.append(x[0] + '/' + y)
            targets.append(x[0][len('Training/'):])
    return paths, targets

def get_all_pictures(path):
    names, targets = take_all_pictures_names(path)
    X = []
    for name in names:
        X.append(plt.imread(name))
    return X, targets

# %%
# Меняем размер картинки
from skimage.transform import resize
def resize_picture(img, shape):
    return resize(img, shape)

# %%
X, y = get_all_pictures('Training/')

# %%
print(y[2000], X[2000].shape)
plt.imshow(X[2000])
# Out:
# C (76, 66, 3)

# %%
plt.imshow(resize_picture(X[2000], (40, 40, 3)))
# Out:
# /home/ilya/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
