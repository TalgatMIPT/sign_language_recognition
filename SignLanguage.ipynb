# %%
import numpy
import cv2

# %%
import matplotlib.pyplot as plt

# %%
IM = cv2.imread('DS_points/scene1-camera1_Liz__frame_1130.jpg')

# %%
cv2.imshow('img', IM)

# %%
imgplot = plt.imshow(IM)

# %%
plt.show()

# %%
IM.shape
# Out:
# (480, 640, 3)

# %%
IM2 = cv2.imread('DS_5letters_test/A/A-test10.jpg')

# %%
IM2.shape
# Out:
# (100, 100, 3)

# %%
imgplot = plt.imshow(IM2)
plt.show()

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
import glob
import tqdm

# %%
image_path = 'dataset5/A/a/'

# %%
IM3 = cv2.imread('dataset5/A/a/color_0_0002.png')

# %%
names = glob.glob(image_path + "*.*")
data = []
for name in tqdm.tqdm_notebook(names):
    image = cv2.imread(name)
    data.append(image)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
names[0]
# Out:
# 'dataset5/A/a/color_0_0458.png'

# %%
plt.imshow(data[0])
plt.show()

# %%
data[0].shape
# Out:
# (124, 98, 3)

# %%
hog_descriptor = cv2.HOGDescriptor((64, 64), #winsize
                                    (32, 32), #blocksize
                                    (16, 16), #blockstride
                                    (8, 8),   #cellsize
                                    9)        #nbins

# %%
hog_descriptor.compute(data[0]).T
# Out:
# array([[  6.03544031e-05,   4.37685094e-06,   1.30971903e-05, ...,
#           5.34176938e-02,   8.06072950e-02,   5.27811386e-02]], dtype=float32)
